# %%
1 == 1
# Out:
# True

# %%
1 == '1'
# Out:
# False

# %%
2 == 2.0
# Out:
# True

# %%
"Hello" == "hello"
# Out:
# False

# %%
"hello" == "hello"
# Out:
# True

# %%
1 != 2
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
1 >= 1
# Out:
# True

# %%
1 <= 2
# Out:
# True

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
(1 < 2) and (2 < 3)
# Out:
# True

# %%
'h' == 'h' or 2 == 3
# Out:
# True

# %%
not 1 == 1
# Out:
# False

# %%
not(1 == 1)
# Out:
# False

# %%
not 2 == 1
# Out:
# True
